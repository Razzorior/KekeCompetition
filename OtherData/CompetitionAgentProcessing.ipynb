# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
solData = pd.read_csv('SolutionStats.csv', usecols=[3])

boxplot = solData.boxplot(vert=False)
boxplot.set_xlabel('Number of Steps')
plt.savefig("BoxPlotSteps.png",format="png")
